# %% [markdown]
# <a href="https://colab.research.google.com/github/fayozkhon/ai-programming-2026/blob/main/week01/week01_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 01주차 연습

# %%
# TODO: 밑줄을 본인 이름과 학과로 바꾸세요.
print('이름:', 'Fayozkhon')
print('학과:', '정보컴퓨터공학과')
# Out:
# 이름: Fayozkhon
# 학과: 정보컴퓨터공학과

# %%
# !git clone https://github.com/octocat/Hello-World.git
# Out:
# Cloning into 'Hello-World'...
# remote: Enumerating objects: 13, done.
# remote: Total 13 (delta 0), reused 0 (delta 0), pack-reused 13 (from 1)
# Receiving objects: 100% (13/13), done.

# %%
# %cd /content/Hello-World
# !ls

print("기대: /content/Hello-World 로 이동한 뒤 README 파일 이름이 출력됩니다")
# Out:
# /content/Hello-World
# README
# 기대: /content/Hello-World 로 이동한 뒤 README 파일 이름이 출력됩니다

# %%
# !ls
# Out:
# Hello-World  sample_data

# %%
# %cd /content/Hello-World
# !ls
# Out:
# /content/Hello-World
# Hello-World  README
